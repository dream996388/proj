# %%
# !git clone https://github.com/dream996388/style-transfer.git
# %cd /content/style-transfer
# Out:
# Cloning into 'style-transfer'...
# remote: Enumerating objects: 2240, done.
# remote: Counting objects: 100% (598/598), done.
# remote: Compressing objects: 100% (485/485), done.
# remote: Total 2240 (delta 122), reused 582 (delta 111), pack-reused 1642
# Receiving objects: 100% (2240/2240), 248.24 MiB | 16.41 MiB/s, done.
# Resolving deltas: 100% (479/479), done.
# Checking out files: 100% (2178/2178), done.
# /content/style-transfer

# %%
# !python3 v9_df+diff_bg.py
# Out:
# spent time: 18.428311347961426
# done
# processed 1 images
# -----------------------------------------------------
# spent time: 7.906477689743042
# done
# processed 2 images
# -----------------------------------------------------
# spent time: 7.870929002761841
# done
# processed 3 images
# -----------------------------------------------------
# spent time: 7.857460021972656
# done
# processed 4 images
# -----------------------------------------------------
# spent time: 7.972583532333374
# done
# processed 5 images
# -----------------------------------------------------
# spent time: 7.993900299072266
# done
# processed 6 images
# -----------------------------------------------------
# spent time: 8.03634238243103
# done
# processed 7 images
# -----------------------------------------------------
# spent time: 7.957695245742798
# done
# processed 8 images
# -----------------------------------------------------
# spent time: 7.939158916473389
# done
# processed 9 images
# ...

# %%
# !zip -r output.zip /content/style-transfer/output/
# Out:
#   adding: content/style-transfer/output/ (stored 0%)
#   adding: content/style-transfer/output/kos08/ (stored 0%)
#   adding: content/style-transfer/output/kos08/Part7/ (stored 0%)
#   adding: content/style-transfer/output/kos08/Part7/content_img.png (deflated 96%)
#   adding: content/style-transfer/output/kos08/Part7/defect_img.png (deflated 3%)
#   adding: content/style-transfer/output/kos08/Part7/style_img.png (deflated 26%)
#   adding: content/style-transfer/output/kos08/Part7/style_seg.png (deflated 91%)
#   adding: content/style-transfer/output/kos08/Part7/output.jpg (deflated 0%)
#   adding: content/style-transfer/output/kos08/Part7/content_seg.png (deflated 90%)
#   adding: content/style-transfer/output/kos08/Part7/bk_img.png (deflated 3%)
#   adding: content/style-transfer/output/kos08/Part5/ (stored 0%)
#   adding: content/style-transfer/output/kos08/Part5/content_img.png (deflated 96%)
#   adding: content/style-transfer/output/kos08/Part5/defect_img.png (deflated 3%)
# ...

# %%
# from google.colab import files
# files.download('/content/style-transfer/output.zip') 

from google.colab import drive
drive.mount('/content/gdrive')
# !mv /content/style-transfer/output.zip /content/gdrive/MyDrive
